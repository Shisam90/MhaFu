# %%
import pandas as pd
from functools import cache

# %%
@cache
def get_dataset():
    return pd.read_csv("dataset.csv", compression="gzip")


dataset = get_dataset()

# %%
dataset.iloc[:,6:15]
# Out:
#         Calories  FatContent  SaturatedFatContent  CholesterolContent
# 0          170.9         2.5                  1.3                 8.0  \
# 1          536.1        24.0                  3.8                 0.0
# 2          103.6         0.4                  0.1                 0.0
# 3          228.0         7.1                  1.7                24.5
# 4            4.3         0.0                  0.0                 0.0
# ...          ...         ...                  ...                 ...
# 375698     422.3        28.6                 12.6               106.0
# 375699      84.3         2.1                  1.2                 6.8
# 375700     358.9        19.8                 10.5               103.1
# 375701     316.6        12.5                  7.6                54.4
# 375702      16.1         0.6                  0.1                 2.9
#
#         SodiumContent  CarbohydrateContent  FiberContent  SugarContent
# ...
